# %%
import nest_asyncio
nest_asyncio.apply()

from main import agent
from pyflow import tools

# %%
"Hi" >> agent

# %%
session = "Hi" >> agent

# %%
"What time is it?" >> session

# %%
"Explain this repository, but don't call too many tools" >> session

# %%
session

# %%
sessions = agent.parallel(["year", "month", "day"], lambda x: f"What {x} is it?")
sessions[2]
