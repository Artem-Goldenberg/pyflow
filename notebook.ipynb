# %%
import nest_asyncio
nest_asyncio.apply()

from main import agent
# Out:
# [03/19/26 11:36:58] INFO     Using credentials directory: /Users/goldenberg/.openhands/auth       ]8;id=682826;file:///Users/goldenberg/Developer/pyflow/.venv/lib/python3.12/site-packages/openhands/sdk/llm/auth/credentials.py\credentials.py]8;;\:]8;id=450367;file:///Users/goldenberg/Developer/pyflow/.venv/lib/python3.12/site-packages/openhands/sdk/llm/auth/credentials.py#57\57]8;;\
# [03/19/26 11:36:58] INFO     Using existing OpenAI credentials                                        ]8;id=855054;file:///Users/goldenberg/Developer/pyflow/.venv/lib/python3.12/site-packages/openhands/sdk/llm/auth/openai.py\openai.py]8;;\:]8;id=769056;file:///Users/goldenberg/Developer/pyflow/.venv/lib/python3.12/site-packages/openhands/sdk/llm/auth/openai.py#659\659]8;;\

# %%
session = "Hi" >> agent
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.Markdown object>
# ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
session

# %%
from pyflow import tools


"What time is it" @tools("terminal") >> session
